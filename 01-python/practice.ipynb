# %% [markdown]
# **Variables, data types, type conversion**

# %%
problem_solved = 3.1
total_problems = 113
topic = "python"
is_complete = False
print(type(is_complete))
print("problem solved:", str(problem_solved))
# Out:
# <class 'bool'>
# problem solved: 3.1

# %%
x = "43"
#print(x+2)  error
print(int(x)+2)
# Out:
# 45
